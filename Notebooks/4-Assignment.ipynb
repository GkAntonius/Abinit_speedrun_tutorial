# %% [markdown]
# # 4. Challenge
#
# Time to combine what you've seen. Pick any of the exercises below -- they
# don't depend on each other.

# %% [markdown]
# ## A. ecut convergence for silicon
#
# Redo the ecut convergence study from `2.1-Convergence_study.ipynb`, but for
# silicon instead of GaAs.
#
# 1. Write a `build_ecut_conv_flow`-style function for Si (`wlib.si_structure()`
#    and `Si.psp8` instead of the GaAs equivalents -- `wlib.gs_input` is a
#    good template).
# 2. Build and run the flow (either in the notebook with
#    `flow.make_scheduler().start()`, or as a standalone script, following
#    the `run_*.py` / `make_*.py` pattern from Notebooks 1-2).
# 3. Analyze it with a `GsrRobot` and `ConvergenceAnalyzer`, as in 2.1.
#
# Is the converged `ecut` similar to the one found for GaAs? Should it be?

# %%
import warnings
warnings.filterwarnings("ignore")

from abipy import abilab
import abipy.flowtk as flowtk
abilab.enable_notebook()

# %matplotlib inline

import workshop_lib as wlib

# Your code here.

# %% [markdown]
# ## B. A new material: diamond
#
# `../Data/Structures/mp-66_C.cif` and `../Data/Pseudos/C.psp8` are already
# in place. Using the patterns from Notebooks 1 and 2, build (some or all
# of): a ground-state run, an ecut convergence study, and a band structure
# for diamond.
#
# Diamond is face-centered cubic, like GaAs and Si, so the same L-Gamma-X
# k-path (`wlib.FCC_KPATH`) applies to its band structure.

# %%
C_CIF = wlib.STRUCTURE_DIR / "mp-66_C.cif"
diamond = abilab.Structure.from_file(str(C_CIF))
print(diamond)
diamond.plot();

# Your code here.

# %% [markdown]
# ## C. Phonon thermodynamics
#
# `2.4-Phonons.ipynb` computed `phdos_file.phdos`, the phonon density of
# states of GaAs. Within the harmonic approximation, a phonon DOS is enough
# to get thermodynamic properties as a function of temperature (internal
# energy, entropy, free energy, heat capacity).
#
# Re-open the phonon DOS file if you closed it:
#
# ```python
# ddb = abilab.abiopen("flow_gaas_phonons/w1/outdata/out_DDB")  # built in 2.4-Phonons.ipynb
# _, phdos_file = ddb.anaget_phbst_and_phdos_files(nqsmall=10, ndivsm=10, dos_method="tetra")
# ```
#
# Then explore `phdos_file.phdos` for harmonic thermodynamic properties --
# tab-completion or `help(phdos_file.phdos)` will show you what's available
# -- and plot the heat capacity $C_v$ as a function of temperature.

# %%
# Your code here.
